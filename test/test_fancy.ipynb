# %% [markdown]
# # Testing out FANCY

# %%
# %matplotlib inline
import sys
sys.path.append('../')
import numpy as np
from fancy import *

# %%
# read in some data

some_data = Data('../soiaporn_model/data/agn_catalog.dat')
uhecr_data = Data('../soiaporn_model/data/auger_UHECR_list.dat')
sources = Source(some_data)

# goal:
#data = Data()
#data.add_source()
#data.add_uhecr()
#data.add_detector('Auger')
#data.show()

uhecrs = Uhecr(uhecr_data)
fig, skymap = uhecrs.plot();
sources.plot(skymap = skymap)
# Out:
# /Users/fran/projects/bayes/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:1707: MatplotlibDeprecationWarning: The axesPatch function was deprecated in version 2.1. Use Axes.patch instead.
#   if limb is not ax.axesPatch:
# (<Figure size 864x432 with 0 Axes>,
#  <fancy.allskymap.allskymap.AllSkyMap at 0x11a32a8d0>)
